# %% [markdown]
# <a href="https://colab.research.google.com/github/DangKhoa8422/Pre-Trained-Models/blob/main/Pre_Trained_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MTCNN (Multi Task Cascaded Convolutional Networks)

# %%
pip install mtcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN 
filename = '/content/sample_data/clb.jpg'
img = plt.imread(filename)
plt.imshow(img)

# %%
detector = MTCNN()
faces = detector.detect_faces(img)
# Out:
# ...
# 14/14 [==============================] - 1s 39ms/step

# %%
for face in faces:
  print(face)
# Out:
# {'box': [995, 754, 54, 63], 'confidence': 0.9999997019767761, 'keypoints': {'left_eye': (1016, 777), 'right_eye': (1039, 779), 'nose': (1029, 793), 'mouth_left': (1015, 802), 'mouth_right': (1035, 803)}}
# {'box': [374, 456, 44, 48], 'confidence': 0.9999989867210388, 'keypoints': {'left_eye': (391, 473), 'right_eye': (411, 474), 'nose': (404, 482), 'mouth_left': (392, 492), 'mouth_right': (410, 492)}}
# {'box': [619, 627, 46, 54], 'confidence': 0.9999987483024597, 'keypoints': {'left_eye': (634, 650), 'right_eye': (655, 646), 'nose': (647, 660), 'mouth_left': (639, 672), 'mouth_right': (656, 669)}}
# {'box': [732, 439, 36, 49], 'confidence': 0.9999913573265076, 'keypoints': {'left_eye': (743, 458), 'right_eye': (760, 458), 'nose': (753, 467), 'mouth_left': (742, 474), 'mouth_right': (761, 474)}}
# ...

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN
filename = '/content/sample_data/clb.jpg'
detector = MTCNN()
faces = detector.detect_faces(img)
plt.imshow(img)
ax = plt.gca()
for face in faces:
  x,y,width,height = face['box']
  rect = plt.Rectangle((x,y), width, height, fill = False, color = 'red')
  ax.add_patch(rect)
  #plt.savefig
#plt.show()
  for key,value in face['keypoints'].items():
    dot = plt.Circle(value, radius = 2, color ='red')
    ax.add_patch(dot)
plt.show()
# Out:
# ...
# 14/14 [==============================] - 1s 38ms/step

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN
filename = '/content/sample_data/clbkhautrang.jpg'
detector = MTCNN()
faces = detector.detect_faces(img)
plt.imshow(img)
ax = plt.gca()
for face in faces:
  x,y,width,height = face['box']
  rect = plt.Rectangle((x,y), width, height, fill = False, color = 'red')
  ax.add_patch(rect)
  #plt.savefig
#plt.show()
  for key,value in face['keypoints'].items():
    dot = plt.Circle(value, radius = 2, color ='red')
    ax.add_patch(dot)
plt.show()
# Out:
# ...
# 14/14 [==============================] - 1s 41ms/step

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN
filename = '/content/sample_data/clbkhautrang.jpg'
detector = MTCNN()
faces = detector.detect_faces(img)
plt.imshow(img)
ax = plt.gca()
for face in faces:
  x,y,width,height = face['box']
  rect = plt.Rectangle((x,y), width, height, fill = False, color = 'red')
  ax.add_patch(rect)
  #plt.savefig
#plt.show()
  for key,value in face['keypoints'].items():
    dot = plt.Circle(value, radius = 2, color ='red')
    ax.add_patch(dot)
plt.show()
# Out:
# ...
# 14/14 [==============================] - 1s 39ms/step
